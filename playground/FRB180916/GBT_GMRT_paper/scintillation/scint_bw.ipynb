# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig

# %%
gbtb = np.load('GBT_B.dm348.8.npy')

# %%
plt.imshow(gbtb, aspect = 'auto')

# %%
print(gbtb.shape)
# Out:
# (512, 256)

# %%
plt.plot(gbtb.sum(1))
