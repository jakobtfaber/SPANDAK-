# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import scipy.signal as ss
from matplotlib import rc
from astropy.modeling.models import Gaussian2D
from photutils.isophote import EllipseGeometry
from photutils import EllipticalAperture
from photutils.isophote import Ellipse
from photutils.isophote import build_ellipse_model
plt.rcParams.update({'font.size': 10})
plt.rc('font', family='serif')

# %%
A = np.load('npy/pulse_251405924.fits.npy')
print(A.shape)
# Out:
# (2048, 2048)

# %%
subfac = 16
sub = rb_sub = np.nanmean(A.reshape(-1, subfac, A.shape[1]), axis=1)
sav = ss.savgol_filter(sub, 49, 6)
print(sav.shape)
sav_c = sav[60:,1200:1800]
fig = plt.figure(figsize = (5, 5))
freq_range = np.arange(600, 1000, 8)
plt.imshow(sav_c, aspect = 'auto')
plt.yticks(np.arange(0, sav_c.shape[0], 37), [800, 700, 600])
plt.xticks(np.arange(0, sav_c.shape[1], 104), [0, 2, 4, 6, 8, 10])
#plt.plot(sav[60:,1200:1800].sum(0))
plt.ylabel('Frequency Channels')
plt.xlabel('Time Bins')
plt.title('Dynamic Spectrum')
fig.savefig('C_dynspec.png')
# Out:
# (128, 2048)

# %%
xhi = 1800
xlo = 1200
yhi = len(sav.sum(1))
ylo = 60


sav_c = sav[ylo:yhi, xlo:xhi]

#Calculate 2D ACF
acf = ss.correlate(sav_c, sav_c)

#Mask acf to eliminate peakiness
#acf[len(acf.sum(1))//2 -1 : len(acf.sum(1))//2 +1, :] \
#    = np.ones(len(acf.sum(0)))*np.mean(acf[len(acf.sum(1))//2 +1:len(acf.sum(1))//2 +5, :])

#Cap acf values
cap = np.mean(acf[len(acf.sum(1))//2 +1:len(acf.sum(1))//2 +2, len(acf.sum(0))//2 +10:len(acf.sum(0))//2 +20])
acf[acf > cap] = cap


#Ellipse Parameters
sma = 20
eps = 0.4
pa = 60 * np.pi/180

#Provide the initial Ellipse to be fitted
#Calculate Ellipse Geometry
geometry = EllipseGeometry(x0 = acf.shape[1]/2, \
            y0 = acf.shape[0]/2, sma = sma, eps = eps, pa = pa)
#Show Initial Guess Ellipsee
aper = EllipticalAperture((geometry.x0, geometry.y0), \
            geometry.sma, geometry.sma*(1-geometry.eps),geometry.pa)

#Plot Initial Guess Ellipse on ACF
fig = plt.figure(figsize = (5, 5))
plt.imshow(acf, aspect = 'auto')
plt.ylabel('Frequency Channels')
plt.xlabel('Time Bins')
plt.title('ACF')
aper.plot(color='white')
#fig.savefig('A.png')

#Fit Ellipse to 2D ACF
try:
    ellipse = Ellipse(acf, geometry)
    isolist = ellipse.fit_image()
    model_image = build_ellipse_model(acf.shape, isolist)
    residual = acf - model_image
    
    smas = np.linspace(10, 100, 5)
    for sma in smas:
        iso = isolist.get_closest(sma)
        x, y, = iso.sampled_coordinates()
        plt.plot(x, y, color='white')
except ValueError:
    print('Note: Value Error')
    pass
except IndexError:
    print('Ellipse Fit Failed!')
    pass
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-50-06b04f005cf7> in <module>
#      43 #Fit Ellipse to 2D ACF
#      44 ellipse = Ellipse(acf, geometry)
# ---> 45 isolist = ellipse.fit_image()
#      46 try:
#      47     model_image = build_ellipse_model(acf.shape, isolist)
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/photutils/isophote/ellipse.py in fit_image(self, sma0, minsma, maxsma, step, conver, minit, maxit, fflag, maxgerr, sclip, nclip, integrmode, linear, maxrit, fix_center, fix_pa, fix_eps)
#     457                                          integrmode, linear, maxrit,
#     458                                          going_inwards=True,
# --> 459                                          isophote_list=isophote_list)
#     460
#     461             # if abnormal condition, fix isophote but keep going.
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/photutils/isophote/ellipse.py in fit_isophote(self, sma, step, conver, minit, maxit, fflag, maxgerr, sclip, nclip, integrmode, linear, maxrit, noniterate, going_inwards, isophote_list)
#     605             isophote = self._iterative(sma, step, linear, geometry, sclip,
#     606                                        nclip, integrmode, conver, minit,
# --> 607                                        maxit, fflag, maxgerr, going_inwards)
#     608
#     609         # store result in list
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/photutils/isophote/ellipse.py in _iterative(self, sma, step, linear, geometry, sclip, nclip, integrmode, conver, minit, maxit, fflag, maxgerr, going_inwards)
#     628
#     629         isophote = fitter.fit(conver, minit, maxit, fflag, maxgerr,
# --> 630                               going_inwards)
#     631
#     632         return isophote
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/photutils/isophote/fitter.py in fit(self, conver, minit, maxit, fflag, maxgerr, going_inwards)
#     211             # the EllipseSample constructor.
#     212             sample = corrector.correct(sample, largest_harmonic)
# --> 213             sample.update(fixed_parameters)
#     214
#     215             # see if any abnormal (or unusual) conditions warrant
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/photutils/isophote/sample.py in update(self, fixed_parameters)
#     294
#     295         # Update the mean value first, using extraction from main sample.
# --> 296         s = self.extract()
#     297         self.mean = np.mean(s[2])
#     298
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/photutils/isophote/sample.py in extract(self)
#     150             return self.values
#     151         else:
# --> 152             s = self._extract()
#     153             self.values = s
#     154             return s
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/photutils/isophote/sample.py in _extract(self, phi_min)
#     213             # do the integration at phi-radius position, and append
#     214             # results to the angles, radii, and intensities lists.
# --> 215             integrator.integrate(radius, phi)
#     216
#     217             # store sector area locally
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/photutils/isophote/integrator.py in integrate(self, radius, phi)
#     176         x_ = radius * math.cos(phi + self._geometry.pa) + self._geometry.x0
#     177         y_ = radius * math.sin(phi + self._geometry.pa) + self._geometry.y0
# --> 178         #x_[x_>1E308] = 0.0
#     179         #y_[y_>1E308] = 0.0
#     180         print(x_, y_)
#
# OverflowError: cannot convert float infinity to integer

# %%
fig = plt.figure(figsize = (10, 10))
ax1 = fig.add_subplot(221)
plt.plot(sav[ylo:yhi, xlo:xhi].sum(0))

ax2 = fig.add_subplot(222)
plt.imshow(sav[ylo:yhi, xlo:xhi], aspect = 'auto')


ax3 = fig.add_subplot(223)
plt.imshow(acf, aspect = 'auto')
plt.ylabel('Frequency Channels')
plt.xlabel('Time Bins')
plt.title('ACF')


ax4 = fig.add_subplot(224)
plt.imshow(sub, interpolation = None, aspect = 'auto')

#plt.gca().invert_yaxis()
plt.show()
