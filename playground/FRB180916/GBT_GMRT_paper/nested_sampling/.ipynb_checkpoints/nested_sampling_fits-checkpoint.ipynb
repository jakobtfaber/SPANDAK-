# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy.signal import convolve
import sys,os
from burst_utils import find_burst, boxcar_kernel
from profile_fits_final_utils import *
MIN_FLOAT = sys.float_info[3]

# %%
#FORMATTING
font = {'family' : 'serif',
        'weight' : 'normal',
        'size'   : 14}

matplotlib.rc('font', **font)

# %%
#ARCHIVE FILE + BURST INFO

#Set relevant burst index
idx = 0 #Order: GBT A - 0, B - 1, C - 2, D - 3, E - 4, F - 5, G - 6, GMRT A - 7, B - 8, C - 9, D - 10

#Get info
npy_fils = burst_info(idx)
# Out:
# Burst:  gbta
# Bandwidth (MHz):  400.0
# Center Frequency (MHz):  800.0
# File Duration (ms):  83.33
# Sampling Time (ms):  0.02034423828125
# Number of Channels:  7680
# Peak Location (grid):  3180
# Peak Width (grid):  1
# Raw Time Resolution (microsec):  20.34423828125
# Raw Frequency Resolution (kHz):  52.083333333333336
# Window (left):  2879
# Window (right):  3481

# %%
#SHAPE 
print('Array Shape:', npy.shape)
# Out:
# Array Shape: (7680, 4096)

# %%
#Plot relevant burst info for nested sampling fits
#Plot timeseries, model & residual
for idx in range(11):
    npy, x, y, y_data, window_right, window_left = burst_info_all(npy_fils, idx)
    fig = plt.figure(figsize = (10, 10))
    plt.plot(x, y_data, c = 'k', linewidth = 2, zorder = 2, label = 'FRB: ' + str(pfits_key))
    plt.plot(x, y, c = 'r', linewidth = 4, linestyle = 'dashed', label = 'ExpGauss Model Fit')
    plt.plot(x, y - y_data - 1., c = 'dodgerblue', linewidth = 2, label = 'Residual')
    #plt.title('GBT C')
    plt.xlabel('Time (ms)')
    plt.legend()
    plt.show()
# Out:
# Burst:  gbta
# Archive File Duration (ms):  83.33
# Bandwidth (MHz):  400.0
# Sigmas:  0.17 0.001 0.001 0.001
# gbta width (ms): 0.41 +/- 0.01
# gbta width (ms): 0.4 +/- 0.01
# Burst:  gbtb
# Archive File Duration (ms):  83.33
# Bandwidth (MHz):  400.0
# Sigmas:  0.18 0.001 1.14 0.1
# gbtb width (ms): 3.35 +/- 0.03
# No Alternative Burst Width
# Burst:  gbtc
# Archive File Duration (ms):  333.33
# Bandwidth (MHz):  400.0
# Sigmas:  2.21 0.001 0.001 0.001
# gbtc width (ms): 5.21 +/- 0.39
# gbtc width (ms): 5.2 +/- 0.39
# Burst:  gbtd
# Archive File Duration (ms):  166.68
# Bandwidth (MHz):  400.0
# Sigmas:  0.83 0.001 0.001 0.001
# gbtd width (ms): 1.96 +/- 0.07
# gbtd width (ms): 1.95 +/- 0.07
# Burst:  gbte
# Archive File Duration (ms):  83.33
# Bandwidth (MHz):  400.0
# Sigmas:  0.67 0.39 0.18 0.001
# gbte width (ms): 2.92 +/- 0.02
# gbte width (ms): 2.75 +/- 0.01
# Burst:  gbtf
# Archive File Duration (ms):  83.33
# Bandwidth (MHz):  400.0
# Sigmas:  0.41 0.29 0.12 0.04
# ...

# %%
csv_file = "FRB20180916B_gbt_gmrt_nestsampfits.csv"
try:
    with open(csv_file, 'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        for data in dict_data:
            writer.writerow(data)
except IOError:
    print("I/O error")

# %%
#Get Burst Profile
#burst_widths = {}
#for k in pfits:
y, burst_width = exp_gauss_4(x, *pfits[str(pfits_key)])
print('Burst Width (ms): ', round(burst_width, 3))
fig = plt.figure(figsize = (10, 10))
plt.plot(x, y_data, c = 'k', linewidth = 2, zorder = 2, label = 'FRB: ' + str(pfits_key))
plt.plot(x, y, c = 'r', linewidth = 4, linestyle = 'dashed', label = 'ExpGauss Model Fit')
plt.plot(x, y - y_data - 1., c = 'dodgerblue', linewidth = 2, label = 'Residual')
#plt.title('GBT C')
plt.xlabel('Time (ms)')
plt.legend()
plt.show()
#plt.xlim(40, 80)
# Out:
# Burst Width (ms):  3.346

# %%
#Calculate Widths - FWHM (50% peak)
print(round(burst_width)
# Out:
#   File "<ipython-input-145-bab42d24ab97>", line 2
#     print(round(burst_width)
#                             ^
# SyntaxError: unexpected EOF while parsing

# %% [raw]
# from scipy.optimize import minimize
#
# lower_bounds = [p0[0]-1*p0[0], p0[1]-1*p0[1], p0[2]-1*p0[2], p0[3]-1*p0[3],
#                 p0[4]-1*p0[4], p0[5]-1*p0[5], p0[6]-1*p0[6], p0[7]-1*p0[7],
#                 p0[8]-1*p0[8], p0[9]-1*p0[9], p0[10]-1*p0[10], p0[11]-1*p0[11],
#                 p0[12]-1*p0[12], p0[13]-1*p0[13], p0[14]-1*p0[14], p0[15]-1*p0[15]]
# upper_bounds = [p0[0]+5*p0[0], p0[1]+5*p0[1], p0[2]+5*p0[2], p0[3]+5*p0[3],
#                 p0[4]+5*p0[4], p0[5]+5*p0[5], p0[6]+5*p0[6], p0[7]+5*p0[7],
#                 p0[8]+5*p0[8], p0[9]+5*p0[9], p0[10]+5*p0[10], p0[11]+5*p0[11],
#                 p0[12]+5*p0[12], p0[13]+5*p0[13], p0[14]+5*p0[14], p0[15]+5*p0[15]]
#
# lower_bounds = [round(i, 1) for i in lower_bounds]
# print(lower_bounds)
# upper_bounds = [round(i, 1) for i in upper_bounds]
# print(upper_bounds)
#
#
# #np.random.seed(42)
# #nll = lambda *args: -lnlike(*args)
# #bound = [(lower_bounds[i], upper_bounds[i]) for i in range(len(p0))]
# #print(bound)
# #soln = minimize(nll, p0, args=(x, y_data), bounds = bound)
#  #= soln.x
# #print(soln.x)

# %% [raw]
# y_fit = exp_gauss_4(x, *soln.x)
# plt.plot(x, y_data)
# plt.plot(x, y_fit)

# %% [raw]
# import emcee
# from tqdm import tqdm
# from dynesty import NestedSampler

# %% [raw]
# #lower_bounds = [p0[0]-1*p0[0], p0[1]-1*p0[1], p0[2]-1*p0[2], p0[3]-1*p0[3]]
# #upper_bounds = [p0[0]+1*p0[0], p0[1]+3*p0[1], p0[2]+4*p0[2], p0[3]+5*p0[3]]
# #lower_bounds = [round(i, 1) for i in lower_bounds]
# #print(lower_bounds)
# #upper_bounds = [round(i, 1) for i in upper_bounds]
# #print(upper_bounds)

# %% [raw]
# def lnprior(theta, lower_bounds, upper_bounds):
#     p0 = theta
#     #lower_bounds = [p0[0]-1/3*p0[0], p0[1]-1/3*p0[1], p0[2]-1/3*p0[2], p0[3]-1/3*p0[3]]#,
#     #               #p0[4]-3*p0[4], p0[5]-3*p0[5], p0[6]-3*p0[6], p0[7]-3*p0[7],
#     #               #p0[8]-3*p0[8], p0[9]-3*p0[9], p0[10]-3*p0[10], p0[11]-3*p0[11],
#     #              #p0[12]-3*p0[12], p0[13]-3*p0[13], p0[14]-3*p0[14], p0[15]-3*p0[15]]
#     #upper_bounds = [p0[0]+1/3*p0[0], p0[1]+1/3*p0[1], p0[2]+1/3*p0[2], p0[3]+1/3*p0[3]]#,
#     #               #p0[4]+5*p0[4], p0[5]+5*p0[5], p0[6]+5*p0[6], p0[7]+5*p0[7],
#     #               #p0[8]+5*p0[8], p0[9]+5*p0[9], p0[10]+5*p0[10], p0[11]+5*p0[11],
#     #               #p0[12]+5*p0[12], p0[13]+5*p0[13], p0[14]+5*p0[14], p0[15]+5*p0[15]]
#     #lower_bounds = [round(i, 1) for i in lower_bounds]
#     #print(lower_bounds)
#     #upper_bounds = [round(i, 1) for i in upper_bounds]
#     #print(upper_bounds)
#     #lower_bounds = [2., 0.5, 0.5, 1.3]
#     #upper_bounds = [5., 1.3, 1., 2.5]
#     #print('Lower Bounds: ', lower_bounds)
#     #print('Upper Bounds: ', upper_bounds)
#     if all(lower_bounds[i] < p0[i] < upper_bounds[i] for i in range(len(theta))) == True:
#             return 0.0
#     return -np.inf
#
# def lnprob(theta, x, y):
#     lp = lnprior(theta, lower_bounds, upper_bounds)
#     if not np.isfinite(lp):
#         return -np.inf
#     return lp + lnlike(theta, x, y)
#
# def ptform(u):
#     return 20. * u - 10.
#
# print(len(p0))

# %% [raw]
# import bilby
# import numpy as np
# import matplotlib.pyplot as plt
#
# # A few simple setup steps
# label = 'frb_profile'
# outdir = 'outdir'
# bilby.utils.check_directory_exists_and_if_not_mkdir(outdir)
#
# # Now we define the injection parameters which we make simulated data with
# injection_parameters = dict(m=0.5, c=0.2)
#
# # For this example, we'll use standard Gaussian noise
#
# # These lines of code generate the fake data. Note the ** just unpacks the
# # contents of the injection_parameters when calling the model function.
# sampling_frequency = 10
# time_duration = 10
# time = np.arange(0, time_duration, 1 / sampling_frequency)
# N = len(time)
# sigma = np.random.normal(1, 0.01, N)
# data = model(time, **injection_parameters) + np.random.normal(0, sigma, N)
#
# # We quickly plot the data to check it looks sensible
# fig, ax = plt.subplots()
# ax.plot(time, data, 'o', label='data')
# ax.plot(time, model(time, **injection_parameters), '--r', label='signal')
# ax.set_xlabel('time')
# ax.set_ylabel('y')
# ax.legend()
# fig.savefig('{}/{}_data.png'.format(outdir, label)
#
# # Now lets instantiate a version of our GaussianLikelihood, giving it
# # the time, data and signal model
# likelihood = bilby.likelihood.GaussianLikelihood(time, data, model, sigma)
#
# # From hereon, the syntax is exactly equivalent to other bilby examples
# # We make a prior
# priors = dict()
# priors['m'] = bilby.core.prior.Uniform(0, 5, 'm')
# priors['c'] = bilby.core.prior.Uniform(-2, 2, 'c')
#
# # And run sampler
# result = bilby.run_sampler(
#     likelihood=likelihood, priors=priors, sampler='dynesty', nlive=500,
#     sample='unif', injection_parameters=injection_parameters, outdir=outdir,
#     label=label)
# result.plot_corner()

# %% [raw]
# prio = lnprior(p0, lower_bounds, upper_bounds)
# print(prio)
# like = lnlike(p0, x, y_data)
# print(like)
# prb = lnprob(p0, x, y_data)
# print(prb)

# %% [raw]
# from dynesty import NestedSampler
# # initialize our nested sampler
# sampler = NestedSampler(lnlike, lnprior(, lower_bounds, upper_bounds), 16)

# %% [raw]
# fig, axes = plt.subplots(len(p0), figsize=(10, 20), sharex=True)
# samples = sampler.get_chain()
# labels = ['p' + str(i) for i in range(len(p0))]
# print(labels)
# for i in range(len(p0)):
#     ax = axes[i]
#     ax.plot(samples[:, :, i], "k", alpha=0.3)
#     ax.set_xlim(0, len(samples))
#     ax.set_ylabel(labels[i])
#     ax.yaxis.set_label_coords(-0.1, 0.5)
#
# axes[-1].set_xlabel("step number")

# %% [raw]
# tau = sampler.get_autocorr_time()
# print(tau)

# %% [raw]
# flat_samples = sampler.get_chain(discard=100, thin=int(np.max(tau) // 2), flat=True)
# print(flat_samples.shape)
# print(flat_samples[2])

# %% [raw]
# import corner
#
# fig = corner.corner(
#     flat_samples, labels=labels, truths = [np.percentile(flat_samples[:, i], [16, 50, 84])[1] for i in range(ndim)]
# )

# %% [raw]
# fit_params = [np.percentile(flat_samples[:, i], [16, 50, 84])[1] for i in range(ndim)]
# print(fit_params)

# %% [raw]
# from IPython.display import display, Math
#
# for i in range(ndim):
#     mcmc = np.percentile(flat_samples[:, i], [16, 50, 84])
#     q = np.diff(mcmc)
#     txt = "\mathrm{{{3}}} = {0:.3f}_{{-{1:.3f}}}^{{{2:.3f}}}"
#     txt = txt.format(mcmc[1], q[0], q[1], labels[i])
#     display(Math(txt))

# %% [raw]
# inds = np.random.randint(len(flat_samples), size=100)
# #for ind in inds:
# #    sample = flat_samples[ind]
# #    plt.plot(x, np.dot(np.vander(x, 2), sample[:2]), "C1", alpha=0.1)
# fit = [np.percentile(flat_samples[:, i], [16, 50, 84])[1] for i in range(ndim)]
# plt.plot(x, exp_gauss_4(x, *fit), c = 'r', label = "fit", zorder = 3)
# plt.plot(x, y_data, "k", label="truth", zorder = 2)
# plt.plot(x, y_data - exp_gauss_4(x, *fit) - 0.25)
# plt.legend(fontsize=14)
# plt.xlabel("x")
# plt.ylabel("y");

# %% [raw]
# plt.plot(y_data - exp_gauss_4(x, *fit))

# %% [raw]
# chisq = lnlike(fit, x, y_data)
# print(chisq)
