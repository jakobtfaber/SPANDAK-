# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import sys

# %%
#for file in os.listdir('.'):
#    if file.endswith('.npy'):
#        array = np.load(str(file))
#        plt.imshow(array, aspect = 'auto')
#        plt.show()
array = np.load('GBT_G_348.8_scrunch8_dt0.0003255599999999997sec_fchan480_bins256.npy')
plt.imshow(array[60:, :], aspect = 'auto')
plt.show()
